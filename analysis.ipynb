# %%
import pandas as pd

# %%
excel = pd.read_excel('data/PRISM-PR2025-Cell-Line-Info_1-21-25.xlsx')
excel.head()
# Out:
#     DepMap_ID Cell Line Name StrippedName Cell Set Pool_ID New Cell Line?  \
# 0  ACH-002515         402-91        40291  PR2025A  ADH002            Yes
# 1  ACH-002054     CCRF-HSB-2     CCRFHSB2  PR2025A  SUS006            Yes
# 2  ACH-001293       CHLA-200      CHLA200  PR2025B  ADH009             No
# 3  ACH-002649        ELF-153       ELF153  PR2025A  MIX003            Yes
# 4  ACH-001349        HD-MB03       HDMB03  PR2025B  ADH008             No
#
#   Genomic data? Growth Patterns DepMap Code      Disease  \
# 0            No        Adherent        LIPO  Soft Tissue
# 1            No      Suspension         TLL     Lymphoid
# 2            No        Adherent        ASTR    CNS/Brain
# 3            No             S&A         AML      Myeloid
# 4            No        Adherent         MBL    CNS/Brain
#
#                      Disease Subtype                Disease Sub-subtype Notes
# 0                        Liposarcoma                        Liposarcoma   NaN
# ...
